# %%
import pickle

# %%
with open('results/redzone/scenario_0/debug/sim_6/calls.pkl', 'rb') as f:
    calls = pickle.load(f)

# %%
methods = [call[0] for call in calls]
set(methods)
# Out:
# {'__init__', 'dose_extended', 'dose_simple', 'step_minute'}
