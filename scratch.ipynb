# %%
import sys
sys.path.insert(0, '/home/ndate/Research/Verse-library/pump/')

# %%
import pickle
from pump.artificial_pancreas_scenario import *
from pump.artificial_pancreas_agent import *
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[11], line 3
#       1 import pickle
#       2 from pump.artificial_pancreas_scenario import *
# ----> 3 from pump.artificial_pancreas_agent import *
#
# File ~/Research/Verse-library/pump/artificial_pancreas_agent.py:15
#      13 EMULATOR_PATH = os.environ["EMULATOR_PATH"]
#      14 sys.path.insert(1, EMULATOR_PATH)
# ---> 15 from pump_wrapper import Pump
#      17 from verse import BaseAgent, Scenario, ScenarioConfig
#      18 from verse.analysis.analysis_tree import TraceType, AnalysisTree
#
# File ~/Research/InsulinPump/pump_wrapper.py:5
#       1 # ideas
#       2 # what happens if i request an extended bolus that fill up half of the IOB array, then another that fills up the array but there's no place for the remaining elements
#       3 #
# ----> 5 from simulate import *
# ...

# %%
with open('results/debug/scenario_0/traces.pkl', 'rb') as f:
    calls = pickle.load(f)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 2
#       1 with open('results/debug/scenario_0/traces.pkl', 'rb') as f:
# ----> 2     calls = pickle.load(f)
#
# ModuleNotFoundError: No module named 'artificial_pancreas_agent'

# %%
# Out:
# {'__init__', 'dose_extended', 'dose_simple', 'step_minute'}
